# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r'C:\Users\brian.pisanechi\OneDrive - CFA Institute\Documents\Alt Data Table V2\instance\tasks.db')

cursor = conn.cursor()

response = cursor.execute("SELECT * FROM 'workflow_step'")

db = pd.DataFrame([row for row in response],columns=[col[0] for col in response.description])

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table in tables:
    print(table[0])
# Out:
# task
# workflow_step

# %%
db
# Out:
#     id                       name  likes              category  task_id  \
# 0    2                       BERT      4                 tools        1
# 1    3              Text-lableing      2         workflow_step        1
# 2    4               Transformers      4                 tools        1
# 3    5  Attention is All You Need      4  influential_research        1
# 4    6         SimpleTransformers      4                 tools        1
# 5    7             Data Gathering      3         workflow_step        2
# 6    8              BeautifulSoup      3                 tools        2
# 7    9                   Selenium      2                 tools        2
# 8   10                       BERT      1  influential_research        1
# 9   11             Data Gathering      0         workflow_step        3
# 10  12                     PyPDF2      0                 tools        3
# 11  13                  tabula-py      0                 tools        3
# ...

# %%
db.to_excel('workflow_step.xlsx')

# %%
db = db.loc[:3]

# %%
db.loc[4] = ((5),('Data Extraction'))

# %%
db.to_sql('task', conn, if_exists='replace', index=False)
# Out:
# 4

# %%
response
# Out:
# (('id', None, None, None, None, None, None),
#  ('use_case', None, None, None, None, None, None),
#  ('data_type', None, None, None, None, None, None),
#  ('ml_tools', None, None, None, None, None, None),
#  ('helpful_chatgpt_prompts', None, None, None, None, None, None),
#  ('influential_research', None, None, None, None, None, None))

# %%
db = pd.DataFrame()

# %%
conn.close()

# %%
db
# Out:
#    id   use_case      data_type ml_tools helpful_chatgpt_prompts  \
# 0   1  Sentiment  Text-Labeling
# 1   2  Sentiment
#
#   influential_research
# 0
# 1
